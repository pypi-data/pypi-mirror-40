# %%
import floatview
import pandas as pd
import requests
import io

# %%
url="https://perso.telecom-paristech.fr/eagan/class/igr204/data/cars.csv"
s=requests.get(url).content
tab = pd.read_csv(io.StringIO(s.decode('utf-8')), index_col=False, sep=';')
tab = tab.drop([0])

# %%
gmw = floatview.GlueManagerWidget(tab, modal=True, label="400Cars")

# %%
#gmw.gluemanager.newView("scatter", ["Cylinders", "MPG"], "CylindersxMPG");
#gmw.gluemanager.newView("parallels", ["Acceleration", "Cylinders", "MPG","Cylinders","Weight"], "Parallel");
#gmw.gluemanager.newView("table", ["Acceleration", "Cylinders", "MPG","Cylinders","Weight"], "Table");
#gmw.gluemanager.newView("histogram", ["Cylinders"], "Cylinders");
#gmw.gluemanager.newView("contour", ["Weight", "MPG"], "CylindersxMPG");
#gmw.gluemanager.newView("errorbar", ["Acceleration", "Cylinders"], "CylindersxMPG");
#gmw.gluemanager.newView("composed_lines", ["Cylinders", "MPG","Weight"], "CylindersxMPG");
#gmw.gluemanager.newView("composed_polyfit_3d", ["MPG","Weight"], "CylindersxMPG");
gmw.gluemanager.newView("scatter3D", ["MPG","Horsepower","Weight"]);
gmw.gluemanager.newView("image", ["MPG","Horsepower","Weight"]);
# Out:
# <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script><script>requirejs.config({paths: { 'plotly': ['https://cdn.plot.ly/plotly-latest.min']},});if(!window._Plotly) {require(['plotly'],function(plotly) {window._Plotly=plotly;});}</script>
# <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script><script>requirejs.config({paths: { 'plotly': ['https://cdn.plot.ly/plotly-latest.min']},});if(!window._Plotly) {require(['plotly'],function(plotly) {window._Plotly=plotly;});}</script>

# %%
#gmw.gluemanager.updateSelection([i+100 for i in range(100)])
#gmw.gluemanager.createSubsetFromSelection(label='new_set')

# %%
'''import numpy as np
x_id = "MPG"
y_id = "Horsepower"
z_id = "Weight"
x_value, x_inv = np.unique(gmw.gluemanager.data[x_id].flatten(), return_inverse=True)
y_value, y_inv = np.unique(gmw.gluemanager.data[y_id].flatten(), return_inverse=True)
print (len(x_value))
print (len(y_value))
z_value = np.zeros((len(x_value), len(y_value)))
#print(x_inv)
#print(y_inv)
#print(x_value)
#print(y_value)

for i, value in enumerate(gmw.gluemanager.data[z_id].flatten()):
    z_value[x_inv[i]][y_inv[i]] = value
    print(i, x_value[x_inv[i]], x_inv[i], y_value[y_inv[i]], y_inv[i], value)

print(z_value.shape)'''
# Out:
# 130
# 94
# 0 18.0 17 130.0 16 3504.
# 1 15.0 7 165.0 34 3693.
# 2 18.0 17 150.0 28 3436.
# 3 16.0 9 150.0 28 3433.
# 4 17.0 13 140.0 23 3449.
# 5 15.0 7 198.0 41 4341.
# 6 14.0 5 220.0 46 4354.
# 7 14.0 5 215.0 45 4312.
# 8 14.0 5 225.0 47 4425.
# 9 15.0 7 190.0 39 3850.
# 10 0 0 115.0 10 3090.
# 11 0 0 165.0 34 4142.
# 12 0 0 153.0 30 4034.
# 13 0 0 175.0 37 4166.
# 14 0 0 175.0 37 3850.
# 15 15.0 7 170.0 36 3563.
# 16 14.0 5 160.0 33 3609.
# 17 0 0 140.0 23 3353.
# 18 15.0 7 150.0 28 3761.
# 19 14.0 5 225.0 47 3086.
# 20 24.0 49 95.00 90 2372.
# 21 22.0 38 95.00 90 2833.
# 22 18.0 17 97.00 92 2774.
# 23 21.0 34 85.00 80 2587.
# 24 27.0 63 88.00 83 2130.
# 25 26.0 58 46.00 49 1835.
# 26 25.0 53 87.00 82 2672.
# 27 24.0 49 90.00 85 2430.
# 28 25.0 53 95.00 90 2375.
# 29 26.0 58 113.0 9 2234.
# 30 21.0 34 90.00 85 2648.
# 31 10.0 1 215.0 45 4615.
# 32 10.0 1 200.0 42 4376.
# 33 11.0 2 210.0 44 4382.
# 34 9.0 129 193.0 40 4732.
# 35 27.0 63 88.00 83 2130.
# 36 28.0 68 90.00 85 2264.
# 37 25.0 53 95.00 90 2228.
# 38 25.0 53 0 0 2046.
# 39 0 0 48.00 50 1978.
# 40 19.0 22 100.0 1 2634.
# 41 16.0 9 105.0 4 3439.
# 42 17.0 13 100.0 1 3329.
# 43 19.0 22 88.00 83 3302.
# 44 18.0 17 100.0 1 3288.
# 45 14.0 5 165.0 34 4209.
# 46 14.0 5 175.0 37 4464.
# 47 14.0 5 153.0 30 4154.
# 48 14.0 5 150.0 28 4096.
# 49 12.0 3 180.0 38 4955.
# 50 13.0 4 170.0 36 4746.
# 51 13.0 4 175.0 37 5140.
# 52 18.0 17 110.0 7 2962.
# 53 22.0 38 72.00 68 2408.
# 54 19.0 22 100.0 1 3282.
# 55 18.0 17 88.00 83 3139.
# 56 23.0 42 86.00 81 2220.
# 57 28.0 68 90.00 85 2123.
# 58 30.0 76 70.00 66 2074.
# 59 30.0 76 76.00 71 2065.
# 60 31.0 80 65.00 61 1773.
# 61 35.0 105 69.00 65 1613.
# 62 27.0 63 60.00 56 1834.
# 63 26.0 58 70.00 66 1955.
# 64 24.0 49 95.00 90 2278.
# 65 25.0 53 80.00 75 2126.
# 66 23.0 42 54.00 54 2254.
# 67 20.0 28 90.00 85 2408.
# 68 21.0 34 86.00 81 2226.
# 69 13.0 4 165.0 34 4274.
# 70 14.0 5 175.0 37 4385.
# 71 15.0 7 150.0 28 4135.
# 72 14.0 5 153.0 30 4129.
# 73 17.0 13 150.0 28 3672.
# 74 11.0 2 208.0 43 4633.
# 75 13.0 4 155.0 31 4502.
# 76 12.0 3 160.0 33 4456.
# 77 13.0 4 190.0 39 4422.
# 78 19.0 22 97.00 92 2330.
# 79 15.0 7 150.0 28 3892.
# 80 13.0 4 130.0 16 4098.
# 81 13.0 4 140.0 23 4294.
# 82 14.0 5 150.0 28 4077.
# 83 18.0 17 112.0 8 2933.
# 84 22.0 38 76.00 71 2511.
# 85 21.0 34 87.00 82 2979.
# 86 26.0 58 69.00 65 2189.
# 87 22.0 38 86.00 81 2395.
# 88 28.0 68 92.00 87 2288.
# 89 23.0 42 97.00 92 2506.
# 90 28.0 68 80.00 75 2164.
# 91 27.0 63 88.00 83 2100.
# 92 13.0 4 175.0 37 4100.
# 93 14.0 5 150.0 28 3672.
# 94 13.0 4 145.0 25 3988.
# 95 14.0 5 137.0 20 4042.
# 96 15.0 7 150.0 28 3777.
# 97 12.0 3 198.0 41 4952.
# 98 13.0 4 150.0 28 4464.
# 99 13.0 4 158.0 32 4363.
# 100 14.0 5 150.0 28 4237.
# 101 13.0 4 215.0 45 4735.
# 102 12.0 3 225.0 47 4951.
# 103 13.0 4 175.0 37 3821.
# 104 18.0 17 105.0 4 3121.
# 105 16.0 9 100.0 1 3278.
# 106 18.0 17 100.0 1 2945.
# 107 18.0 17 88.00 83 3021.
# 108 23.0 42 95.00 90 2904.
# 109 26.0 58 46.00 49 1950.
# 110 11.0 2 150.0 28 4997.
# 111 12.0 3 167.0 35 4906.
# 112 13.0 4 170.0 36 4654.
# 113 12.0 3 180.0 38 4499.
# 114 18.0 17 100.0 1 2789.
# 115 20.0 28 88.00 83 2279.
# 116 21.0 34 72.00 68 2401.
# 117 22.0 38 94.00 89 2379.
# 118 18.0 17 90.00 85 2124.
# 119 19.0 22 85.00 80 2310.
# 120 21.0 34 107.0 5 2472.
# 121 26.0 58 90.00 85 2265.
# 122 15.0 7 145.0 25 4082.
# 123 16.0 9 230.0 48 4278.
# 124 29.0 72 49.00 51 1867.
# 125 24.0 49 75.00 70 2158.
# 126 20.0 28 91.00 86 2582.
# 127 19.0 22 112.0 8 2868.
# 128 15.0 7 150.0 28 3399.
# 129 24.0 49 110.0 7 2660.
# 130 20.0 28 122.0 13 2807.
# 131 11.0 2 180.0 38 3664.
# 132 20.0 28 95.00 90 3102.
# 133 21.0 34 0 0 2875.
# 134 19.0 22 100.0 1 2901.
# 135 15.0 7 100.0 1 3336.
# 136 31.0 80 67.00 63 1950.
# 137 26.0 58 80.00 75 2451.
# 138 32.0 86 65.00 61 1836.
# 139 25.0 53 75.00 70 2542.
# 140 16.0 9 100.0 1 3781.
# 141 16.0 9 110.0 7 3632.
# 142 18.0 17 105.0 4 3613.
# 143 16.0 9 140.0 23 4141.
# 144 13.0 4 150.0 28 4699.
# 145 14.0 5 150.0 28 4457.
# 146 14.0 5 140.0 23 4638.
# 147 14.0 5 150.0 28 4257.
# 148 29.0 72 83.00 78 2219.
# 149 26.0 58 67.00 63 1963.
# 150 26.0 58 78.00 73 2300.
# 151 31.0 80 52.00 52 1649.
# 152 32.0 86 61.00 57 2003.
# 153 28.0 68 75.00 70 2125.
# 154 24.0 49 75.00 70 2108.
# 155 26.0 58 75.00 70 2246.
# 156 24.0 49 97.00 92 2489.
# 157 26.0 58 93.00 88 2391.
# 158 31.0 80 67.00 63 2000.
# 159 19.0 22 95.00 90 3264.
# 160 18.0 17 105.0 4 3459.
# 161 15.0 7 72.00 68 3432.
# 162 15.0 7 72.00 68 3158.
# 163 16.0 9 170.0 36 4668.
# 164 15.0 7 145.0 25 4440.
# 165 16.0 9 150.0 28 4498.
# 166 14.0 5 148.0 26 4657.
# 167 17.0 13 110.0 7 3907.
# 168 16.0 9 105.0 4 3897.
# 169 15.0 7 110.0 7 3730.
# 170 18.0 17 95.00 90 3785.
# 171 21.0 34 110.0 7 3039.
# 172 20.0 28 110.0 7 3221.
# 173 13.0 4 129.0 15 3169.
# 174 29.0 72 75.00 70 2171.
# 175 23.0 42 83.00 78 2639.
# 176 20.0 28 100.0 1 2914.
# 177 23.0 42 78.00 73 2592.
# 178 24.0 49 96.00 91 2702.
# 179 25.0 53 71.00 67 2223.
# 180 24.0 49 97.00 92 2545.
# 181 18.0 17 97.00 92 2984.
# 182 29.0 72 70.00 66 1937.
# 183 19.0 22 90.00 85 3211.
# 184 23.0 42 95.00 90 2694.
# 185 23.0 42 88.00 83 2957.
# 186 22.0 38 98.00 93 2945.
# 187 25.0 53 115.0 10 2671.
# 188 33.0 94 53.00 53 1795.
# 189 28.0 68 86.00 81 2464.
# 190 25.0 53 81.00 76 2220.
# 191 25.0 53 92.00 87 2572.
# 192 26.0 58 79.00 74 2255.
# 193 27.0 63 83.00 78 2202.
# 194 17.5 14 140.0 23 4215.
# 195 16.0 9 150.0 28 4190.
# 196 15.5 8 120.0 12 3962.
# 197 14.5 6 152.0 29 4215.
# 198 22.0 38 100.0 1 3233.
# 199 22.0 38 105.0 4 3353.
# 200 24.0 49 81.00 76 3012.
# 201 22.5 41 90.00 85 3085.
# 202 29.0 72 52.00 52 2035.
# 203 24.5 52 60.00 56 2164.
# 204 29.0 72 70.00 66 1937.
# 205 33.0 94 53.00 53 1795.
# 206 20.0 28 100.0 1 3651.
# 207 18.0 17 78.00 73 3574.
# 208 18.5 20 110.0 7 3645.
# 209 17.5 14 95.00 90 3193.
# 210 29.5 73 71.00 67 1825.
# 211 32.0 86 70.00 66 1990.
# 212 28.0 68 75.00 70 2155.
# 213 26.5 60 72.00 68 2565.
# 214 20.0 28 102.0 2 3150.
# 215 13.0 4 150.0 28 3940.
# 216 19.0 22 88.00 83 3270.
# 217 19.0 22 108.0 6 2930.
# 218 16.5 11 120.0 12 3820.
# 219 16.5 11 180.0 38 4380.
# 220 13.0 4 145.0 25 4055.
# 221 13.0 4 130.0 16 3870.
# 222 13.0 4 150.0 28 3755.
# 223 31.5 82 68.00 64 2045.
# 224 30.0 76 80.00 75 2155.
# 225 36.0 108 58.00 55 1825.
# 226 25.5 56 96.00 91 2300.
# 227 33.5 95 70.00 66 1945.
# 228 17.5 14 145.0 25 3880.
# 229 17.0 13 110.0 7 4060.
# 230 15.5 8 145.0 25 4140.
# 231 15.0 7 130.0 16 4295.
# 232 17.5 14 110.0 7 3520.
# 233 20.5 31 105.0 4 3425.
# 234 19.0 22 100.0 1 3630.
# 235 18.5 20 98.00 93 3525.
# 236 16.0 9 180.0 38 4220.
# 237 15.5 8 170.0 36 4165.
# 238 15.5 8 190.0 39 4325.
# 239 16.0 9 149.0 27 4335.
# 240 29.0 72 78.00 73 1940.
# 241 24.5 52 88.00 83 2740.
# 242 26.0 58 75.00 70 2265.
# 243 25.5 56 89.00 84 2755.
# 244 30.5 77 63.00 59 2051.
# 245 33.5 95 83.00 78 2075.
# 246 30.0 76 67.00 63 1985.
# 247 30.5 77 78.00 73 2190.
# 248 22.0 38 97.00 92 2815.
# 249 21.5 36 110.0 7 2600.
# 250 21.5 36 110.0 7 2720.
# 251 43.1 123 48.00 50 1985.
# 252 36.1 109 66.00 62 1800.
# 253 32.8 92 52.00 52 1985.
# 254 39.4 119 70.00 66 2070.
# 255 36.1 109 60.00 56 1800.
# 256 19.9 27 110.0 7 3365.
# 257 19.4 25 140.0 23 3735.
# 258 20.2 29 139.0 22 3570.
# 259 19.2 24 105.0 4 3535.
# 260 20.5 31 95.00 90 3155.
# 261 20.2 29 85.00 80 2965.
# 262 25.1 54 88.00 83 2720.
# 263 20.5 31 100.0 1 3430.
# 264 19.4 25 90.00 85 3210.
# 265 20.6 32 105.0 4 3380.
# 266 20.8 33 85.00 80 3070.
# 267 18.6 21 110.0 7 3620.
# 268 18.1 18 120.0 12 3410.
# 269 19.2 24 145.0 25 3425.
# 270 17.7 16 165.0 34 3445.
# 271 18.1 18 139.0 22 3205.
# 272 17.5 14 140.0 23 4080.
# 273 30.0 76 68.00 64 2155.
# 274 27.5 66 95.00 90 2560.
# 275 27.2 64 97.00 92 2300.
# 276 30.9 79 75.00 70 2230.
# 277 21.1 35 95.00 90 2515.
# 278 23.2 43 105.0 4 2745.
# 279 23.8 47 85.00 80 2855.
# 280 23.9 48 97.00 92 2405.
# 281 20.3 30 103.0 3 2830.
# 282 17.0 13 125.0 14 3140.
# 283 21.6 37 115.0 10 2795.
# 284 16.2 10 133.0 18 3410.
# 285 31.5 82 71.00 67 1990.
# 286 29.5 73 68.00 64 2135.
# 287 21.5 36 115.0 10 3245.
# 288 19.8 26 85.00 80 2990.
# 289 22.3 39 88.00 83 2890.
# 290 20.2 29 90.00 85 3265.
# 291 20.6 32 110.0 7 3360.
# 292 17.0 13 130.0 16 3840.
# 293 17.6 15 129.0 15 3725.
# 294 16.5 11 138.0 21 3955.
# 295 18.2 19 135.0 19 3830.
# 296 16.9 12 155.0 31 4360.
# 297 15.5 8 142.0 24 4054.
# 298 19.2 24 125.0 14 3605.
# 299 18.5 20 150.0 28 3940.
# 300 31.9 85 71.00 67 1925.
# 301 34.1 99 65.00 61 1975.
# 302 35.7 107 80.00 75 1915.
# 303 27.4 65 80.00 75 2670.
# 304 25.4 55 77.00 72 3530.
# 305 23.0 42 125.0 14 3900.
# 306 27.2 64 71.00 67 3190.
# 307 23.9 48 90.00 85 3420.
# 308 34.2 100 70.00 66 2200.
# 309 34.5 103 70.00 66 2150.
# 310 31.8 84 65.00 61 2020.
# 311 37.3 113 69.00 65 2130.
# 312 28.4 70 90.00 85 2670.
# 313 28.8 71 115.0 10 2595.
# 314 26.8 62 115.0 10 2700.
# 315 33.5 95 90.00 85 2556.
# 316 41.5 122 76.00 71 2144.
# 317 38.1 116 60.00 56 1968.
# 318 32.1 87 70.00 66 2120.
# 319 37.2 112 65.00 61 2019.
# 320 28.0 68 90.00 85 2678.
# 321 26.4 59 88.00 83 2870.
# 322 24.3 51 90.00 85 3003.
# 323 19.1 23 90.00 85 3381.
# 324 34.3 101 78.00 73 2188.
# 325 29.8 74 90.00 85 2711.
# 326 31.3 81 75.00 70 2542.
# 327 37.0 111 92.00 87 2434.
# 328 32.2 88 75.00 70 2265.
# 329 46.6 128 65.00 61 2110.
# 330 27.9 67 105.0 4 2800.
# 331 40.8 120 65.00 61 2110.
# 332 44.3 126 48.00 50 2085.
# 333 43.4 124 48.00 50 2335.
# 334 36.4 110 67.00 63 2950.
# 335 30.0 76 67.00 63 3250.
# 336 44.6 127 67.00 63 1850.
# 337 40.9 121 0 0 1835.
# 338 33.8 97 67.00 63 2145.
# 339 29.8 74 62.00 58 1845.
# 340 32.7 91 132.0 17 2910.
# 341 23.7 46 100.0 1 2420.
# 342 35.0 105 88.00 83 2500.
# 343 23.6 45 0 0 2905.
# 344 32.4 90 72.00 68 2290.
# 345 27.2 64 84.00 79 2490.
# 346 26.6 61 84.00 79 2635.
# 347 25.8 57 92.00 87 2620.
# 348 23.5 44 110.0 7 2725.
# 349 30.0 76 84.00 79 2385.
# 350 39.1 118 58.00 55 1755.
# 351 39.0 117 64.00 60 1875.
# 352 35.1 106 60.00 56 1760.
# 353 32.3 89 67.00 63 2065.
# 354 37.0 111 65.00 61 1975.
# 355 37.7 114 62.00 58 2050.
# 356 34.1 99 68.00 64 1985.
# 357 34.7 104 63.00 59 2215.
# 358 34.4 102 65.00 61 2045.
# 359 29.9 75 65.00 61 2380.
# 360 33.0 94 74.00 69 2190.
# 361 34.5 103 0 0 2320.
# 362 33.7 96 75.00 70 2210.
# 363 32.4 90 75.00 70 2350.
# 364 32.9 93 100.0 1 2615.
# 365 31.6 83 74.00 69 2635.
# 366 28.1 69 80.00 75 3230.
# 367 0 0 110.0 7 2800.
# 368 30.7 78 76.00 71 3160.
# 369 25.4 55 116.0 11 2900.
# 370 24.2 50 120.0 12 2930.
# 371 22.4 40 110.0 7 3415.
# 372 26.6 61 105.0 4 3725.
# 373 20.2 29 88.00 83 3060.
# 374 17.6 15 85.00 80 3465.
# 375 28.0 68 88.00 83 2605.
# 376 27.0 63 88.00 83 2640.
# 377 34.0 98 88.00 83 2395.
# 378 31.0 80 85.00 80 2575.
# 379 29.0 72 84.00 79 2525.
# 380 27.0 63 90.00 85 2735.
# 381 24.0 49 92.00 87 2865.
# 382 23.0 42 0 0 3035.
# 383 36.0 108 74.00 69 1980.
# 384 37.0 111 68.00 64 2025.
# 385 31.0 80 68.00 64 1970.
# 386 38.0 115 63.00 59 2125.
# 387 36.0 108 70.00 66 2125.
# 388 36.0 108 88.00 83 2160.
# 389 36.0 108 75.00 70 2205.
# 390 34.0 98 70.00 66 2245
# 391 38.0 115 67.00 63 1965.
# 392 32.0 86 67.00 63 1965.
# 393 38.0 115 67.00 63 1995.
# 394 25.0 53 110.0 7 2945.
# 395 38.0 115 85.00 80 3015.
# 396 26.0 58 92.00 87 2585.
# 397 22.0 38 112.0 8 2835
# 398 32.0 86 96.00 91 2665.
# 399 36.0 108 84.00 79 2370.
# 400 27.0 63 90.00 85 2950.
# 401 27.0 63 86.00 81 2790.
# 402 44.0 125 52.00 52 2130.
# 403 32.0 86 84.00 79 2295.
# 404 28.0 68 79.00 74 2625.
# 405 31.0 80 82.00 77 2720.
# (130, 94)

# %%
z_value[7,36]
# Out:
# 3563.0
